# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("H:\\AiQuest\\Ai& ML\\practice\\class 15\\uci breast cancer dataset.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df = df.drop(['id', 'Unnamed: 32'], axis = 1)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
sns.countplot(x = 'diagnosis', data=df)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
df.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
from pandas.core.dtypes.common import is_numeric_dtype

for column in df.columns:
    if is_numeric_dtype(df[column]):
        continue
    else:
        df[column] = label.fit_transform(df[column])

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %% [markdown]
# # seperate train and test data (x, y)

# %%
x = df.drop('diagnosis',axis=1)

# %%
y = df[['diagnosis']]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,train_size=.75, random_state=42)

# %% [markdown]
# # Apply XgBoost Classifier

# %%
import xgboost 
from xgboost import XGBClassifier
xgb_obj = XGBClassifier()

# %%
xgb_obj.fit(xtrain,ytrain)
xgb_obj.score(xtest,ytest)
# Out:
# 0.965034965034965

# %% [markdown]
# # Randomized Search CV

# %%
## Hyperparameter optimization using RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
booster = ['gbtree', 'gblinear', 'dart']

# %%
trees = np.random.randint(15,150,30)

# %%
params={
 "learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ],
 "n_estimators" :      trees,
    "booster"   :      booster
    
}

# %%
classifier = xgboost.XGBClassifier()

# %%
random_search = RandomizedSearchCV(classifier,param_distributions=params,n_iter= 10,scoring='roc_auc',n_jobs=-1,cv=5,verbose=3)

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
from datetime import datetime

start_time = timer(None) # timing starts from this point for "start_time" variable
random_search.fit(xtrain,ytrain)

timer(start_time) # timing ends here for "start_time" variable
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
#
#  Time taken: 0 hours 0 minutes and 4.57 seconds.

# %%
random_search.cv_results_
# Out:
# {'mean_fit_time': array([0.042384  , 0.90418177, 0.04970345, 0.02432313, 0.07217116,
#         0.49709749, 0.03047414, 0.04289398, 0.0534296 , 0.02256689]),
#  'std_fit_time': array([0.00531779, 0.01545168, 0.00537519, 0.00720662, 0.00760001,
#         0.06185402, 0.00933047, 0.0042353 , 0.00761528, 0.00554189]),
#  'mean_score_time': array([0.00936265, 0.03360844, 0.00507383, 0.00937409, 0.00624909,
#         0.02596054, 0.00559287, 0.00233045, 0.00634971, 0.00597634]),
#  'std_score_time': array([0.00338755, 0.00435447, 0.00212591, 0.00765392, 0.00765355,
#         0.00844743, 0.00564846, 0.0044155 , 0.00555401, 0.00644362]),
#  'param_n_estimators': masked_array(data=[81, 143, 112, 17, 94, 112, 40, 115, 73, 60],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_child_weight': masked_array(data=[5, 1, 1, 5, 5, 3, 7, 7, 7, 7],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[5, 3, 4, 10, 3, 10, 3, 3, 12, 6],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_learning_rate': masked_array(data=[0.2, 0.2, 0.1, 0.3, 0.1, 0.15, 0.25, 0.05, 0.05, 0.15],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_gamma': masked_array(data=[0.2, 0.2, 0.1, 0.4, 0.1, 0.3, 0.3, 0.1, 0.0, 0.2],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_colsample_bytree': masked_array(data=[0.3, 0.5, 0.5, 0.7, 0.4, 0.3, 0.4, 0.7, 0.3, 0.7],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_booster': masked_array(data=['gblinear', 'dart', 'gblinear', 'gbtree', 'gbtree',
#                     'dart', 'gbtree', 'gblinear', 'gbtree', 'gblinear'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'n_estimators': 81,
#    'min_child_weight': 5,
#    'max_depth': 5,
#    'learning_rate': 0.2,
#    'gamma': 0.2,
#    'colsample_bytree': 0.3,
#    'booster': 'gblinear'},
#   {'n_estimators': 143,
#    'min_child_weight': 1,
#    'max_depth': 3,
#    'learning_rate': 0.2,
#    'gamma': 0.2,
#    'colsample_bytree': 0.5,
#    'booster': 'dart'},
#   {'n_estimators': 112,
#    'min_child_weight': 1,
#    'max_depth': 4,
#    'learning_rate': 0.1,
#    'gamma': 0.1,
#    'colsample_bytree': 0.5,
#    'booster': 'gblinear'},
#   {'n_estimators': 17,
#    'min_child_weight': 5,
#    'max_depth': 10,
#    'learning_rate': 0.3,
#    'gamma': 0.4,
#    'colsample_bytree': 0.7,
#    'booster': 'gbtree'},
#   {'n_estimators': 94,
#    'min_child_weight': 5,
#    'max_depth': 3,
#    'learning_rate': 0.1,
#    'gamma': 0.1,
#    'colsample_bytree': 0.4,
#    'booster': 'gbtree'},
#   {'n_estimators': 112,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'learning_rate': 0.15,
#    'gamma': 0.3,
#    'colsample_bytree': 0.3,
#    'booster': 'dart'},
#   {'n_estimators': 40,
#    'min_child_weight': 7,
#    'max_depth': 3,
#    'learning_rate': 0.25,
#    'gamma': 0.3,
#    'colsample_bytree': 0.4,
#    'booster': 'gbtree'},
#   {'n_estimators': 115,
#    'min_child_weight': 7,
#    'max_depth': 3,
#    'learning_rate': 0.05,
#    'gamma': 0.1,
#    'colsample_bytree': 0.7,
#    'booster': 'gblinear'},
#   {'n_estimators': 73,
#    'min_child_weight': 7,
#    'max_depth': 12,
#    'learning_rate': 0.05,
#    'gamma': 0.0,
#    'colsample_bytree': 0.3,
#    'booster': 'gbtree'},
#   {'n_estimators': 60,
#    'min_child_weight': 7,
#    'max_depth': 6,
#    'learning_rate': 0.15,
#    'gamma': 0.2,
#    'colsample_bytree': 0.7,
#    'booster': 'gblinear'}],
#  'split0_test_score': array([0.99652778, 0.99768519, 0.99421296, 0.99884259, 1.        ,
#         1.        , 1.        , 0.98553241, 0.99710648, 0.99131944]),
#  'split1_test_score': array([0.98148148, 0.96893668, 0.97729988, 0.96266428, 0.96893668,
#         0.96714456, 0.96057348, 0.97371565, 0.96475508, 0.97789725]),
#  'split2_test_score': array([0.99761051, 1.        , 0.99761051, 0.99880526, 0.99940263,
#         1.        , 0.99880526, 0.99641577, 0.99820789, 0.99641577]),
#  'split3_test_score': array([0.9557783 , 0.98466981, 0.95459906, 0.98378538, 0.98643868,
#         0.98290094, 0.98349057, 0.95165094, 0.98054245, 0.95518868]),
#  'split4_test_score': array([0.9870283 , 0.99705189, 0.98466981, 0.9946934 , 0.99646226,
#         0.99587264, 0.99882075, 0.98349057, 0.99410377, 0.98466981]),
#  'mean_test_score': array([0.98368528, 0.98966871, 0.98167845, 0.98775818, 0.99024805,
#         0.98918363, 0.98833801, 0.97816107, 0.98694313, 0.98109819]),
#  'std_test_score': array([0.01518996, 0.01166462, 0.01531247, 0.01370027, 0.01171503,
#         0.01268009, 0.01516457, 0.01508988, 0.01276512, 0.01437642]),
#  'rank_test_score': array([ 7,  2,  8,  5,  1,  3,  4, 10,  6,  9])}

# %%
tuning_result = pd.DataFrame(random_search.cv_results_)
tuning_result
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.042384      0.005318         0.009363        0.003388
# 1       0.904182      0.015452         0.033608        0.004354
# 2       0.049703      0.005375         0.005074        0.002126
# 3       0.024323      0.007207         0.009374        0.007654
# 4       0.072171      0.007600         0.006249        0.007654
# 5       0.497097      0.061854         0.025961        0.008447
# 6       0.030474      0.009330         0.005593        0.005648
# 7       0.042894      0.004235         0.002330        0.004416
# 8       0.053430      0.007615         0.006350        0.005554
# 9       0.022567      0.005542         0.005976        0.006444
#
#   param_n_estimators param_min_child_weight param_max_depth  \
# 0                 81                      5               5
# 1                143                      1               3
# 2                112                      1               4
# 3                 17                      5              10
# 4                 94                      5               3
# 5                112                      3              10
# 6                 40                      7               3
# 7                115                      7               3
# 8                 73                      7              12
# 9                 60                      7               6
#
#   param_learning_rate param_gamma param_colsample_bytree param_booster  \
# 0                 0.2         0.2                    0.3      gblinear
# 1                 0.2         0.2                    0.5          dart
# 2                 0.1         0.1                    0.5      gblinear
# 3                 0.3         0.4                    0.7        gbtree
# 4                 0.1         0.1                    0.4        gbtree
# 5                0.15         0.3                    0.3          dart
# 6                0.25         0.3                    0.4        gbtree
# 7                0.05         0.1                    0.7      gblinear
# 8                0.05         0.0                    0.3        gbtree
# 9                0.15         0.2                    0.7      gblinear
#
#                                               params  split0_test_score  \
# 0  {'n_estimators': 81, 'min_child_weight': 5, 'm...           0.996528
# 1  {'n_estimators': 143, 'min_child_weight': 1, '...           0.997685
# 2  {'n_estimators': 112, 'min_child_weight': 1, '...           0.994213
# 3  {'n_estimators': 17, 'min_child_weight': 5, 'm...           0.998843
# 4  {'n_estimators': 94, 'min_child_weight': 5, 'm...           1.000000
# 5  {'n_estimators': 112, 'min_child_weight': 3, '...           1.000000
# 6  {'n_estimators': 40, 'min_child_weight': 7, 'm...           1.000000
# 7  {'n_estimators': 115, 'min_child_weight': 7, '...           0.985532
# 8  {'n_estimators': 73, 'min_child_weight': 7, 'm...           0.997106
# 9  {'n_estimators': 60, 'min_child_weight': 7, 'm...           0.991319
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.981481           0.997611           0.955778           0.987028
# 1           0.968937           1.000000           0.984670           0.997052
# 2           0.977300           0.997611           0.954599           0.984670
# 3           0.962664           0.998805           0.983785           0.994693
# 4           0.968937           0.999403           0.986439           0.996462
# 5           0.967145           1.000000           0.982901           0.995873
# 6           0.960573           0.998805           0.983491           0.998821
# 7           0.973716           0.996416           0.951651           0.983491
# 8           0.964755           0.998208           0.980542           0.994104
# 9           0.977897           0.996416           0.955189           0.984670
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.983685        0.015190                7
# 1         0.989669        0.011665                2
# 2         0.981678        0.015312                8
# 3         0.987758        0.013700                5
# 4         0.990248        0.011715                1
# 5         0.989184        0.012680                3
# 6         0.988338        0.015165                4
# 7         0.978161        0.015090               10
# 8         0.986943        0.012765                6
# 9         0.981098        0.014376                9

# %%
random_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.4,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.1, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=3, max_leaves=0, min_child_weight=5, missing=nan,
#               monotone_constraints='()', n_estimators=94, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
random_search.best_score_
# Out:
# 0.9902480500890422

# %%
random_search.best_params_
# Out:
# {'n_estimators': 94,
#  'min_child_weight': 5,
#  'max_depth': 3,
#  'learning_rate': 0.1,
#  'gamma': 0.1,
#  'colsample_bytree': 0.4,
#  'booster': 'gbtree'}

# %%
random_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.4,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.1, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=3, max_leaves=0, min_child_weight=5, missing=nan,
#               monotone_constraints='()', n_estimators=94, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
best_model= random_search.best_estimator_

# %%
best_model.fit(xtrain, ytrain)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.4,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.1, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=3, max_leaves=0, min_child_weight=5, missing=nan,
#               monotone_constraints='()', n_estimators=94, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
best_model.score(xtest, ytest)
# Out:
# 0.972027972027972

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(best_model,xtrain,ytrain,cv=20)

# %%
score
# Out:
# array([1.        , 1.        , 1.        , 0.95454545, 0.95454545,
#        0.95454545, 0.85714286, 0.95238095, 1.        , 1.        ,
#        0.95238095, 1.        , 1.        , 1.        , 1.        ,
#        0.9047619 , 1.        , 0.95238095, 0.9047619 , 0.95238095])

# %%
score.mean()
# Out:
# 0.9669913419913421
